# %% [markdown]
# ## Lección 18: Ambientes Virtuales.

# %% [markdown]
# La siguiente es una rutina para crear un ambiente virtual, se debe seguir esta receta para cada nuevo proyecto:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
